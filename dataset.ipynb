# %%
import os
import ssl
import certifi
import urllib.request

# Força o uso do bundle de certificados do certifi
os.environ["SSL_CERT_FILE"] = certifi.where()

# Verificação da URL segura
print("Certificado SSL forçado para:", os.environ["SSL_CERT_FILE"])
response = urllib.request.urlopen("https://www.ncbi.nlm.nih.gov")
print("Conexão segura com NCBI! Status:", response.status)
# Out:
# Certificado SSL forçado para: /Users/mariacarvalho/Documents/GitHub/Bioinformatics-Project/.venv/lib/python3.9/site-packages/certifi/cacert.pem
# Conexão segura com NCBI! Status: 200

# %% [markdown]
# This script aims to retrieve and process phage genome information that infect *Escherichia coli* from the GenBank database. It uses the Biopython library to query GenBank for relevant genome entries and extracts information for each phage genome.

# %%
import pandas as pd
import re
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "pocawaves@gmail.com"

def search_phages_hosts(host):
    query = f'({host}[host]) OR ({host}[lab_host])'
    handle = Entrez.esearch(db="nucleotide", term=f"{host}[host] AND phage[title]", retmax=100)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

def genomes(ids):
    data = []

    for id in ids:
        handle = Entrez.efetch(db="nucleotide", id=id, rettype="gb", retmode="text")
        record = SeqIO.read(handle, "genbank")
        handle.close()
        print(f"Genome: {record.id} - {record.description}")

        accession_number = record.id
        description = record.description

        host = None
        lab_host = None

        for feature in record.features:
            if feature.type == "source":
                host = feature.qualifiers.get("host", [None])[0]
                lab_host = feature.qualifiers.get("lab_host", [None])[0]


        phage_description = re.sub(r"(complete genome|Escherichia|,)", "", description).strip()

        data.append([accession_number, host, lab_host, phage_description])
    
    return data

ids_fagos = search_phages_hosts("Escherichia coli")

data = genomes(ids_fagos)
# Out:
# Genome: PV287706.1 - Escherichia phage Midge, complete genome
# Genome: PV252060.1 - Escherichia phage nithesis, complete genome
# Genome: PV204681.1 - Escherichia phage vB_EcoM_JQD51, complete genome
# Genome: PP453689.1 - Escherichia phage vB_EcoP_LHP, complete genome
# Genome: PV245935.1 - Escherichia phage kaset, complete genome
# Genome: PV245934.1 - Escherichia phage sutha, complete genome
# Genome: PV245933.1 - Escherichia phage nasanit, complete genome
# Genome: PQ738613.1 - Escherichia phage PhiKM, partial genome
# Genome: PV287714.1 - Escherichia phage HMD-9, complete genome
# Genome: PV191315.1 - Escherichia phage vB_EcoM-P3322, complete genome
# Genome: PQ474795.1 - Escherichia phage vB_Eco_AMO_3701M, complete genome
# Genome: NC_105115.1 - Escherichia phage IrmaTschudi, complete genome
# Genome: NC_105113.1 - Escherichia phage GreteKellenberger, complete genome
# Genome: PP481222.1 - Escherichia phage vB_EcoM_BL, complete genome
# Genome: PP481221.1 - Escherichia phage vB_EcoP_IUE, complete genome
# Genome: NC_106733.1 - Salmonella phage GRNsp8, complete genome
# Genome: NC_133255.1 - Escherichia phage vB_EcoS-26175I, complete genome
# Genome: PV390659.2 - Escherichia phage vB_EcoM_P8, complete genome
# Genome: PV435126.1 - Escherichia phage EPFV3-03/2025, complete genome
# Genome: PV446873.1 - Klebsiella phage KPN234, complete genome
# Genome: PV464739.1 - Escherichia phage RCIP0363, complete genome
# Genome: PV464738.1 - Escherichia phage RCIP0319, complete genome
# Genome: PV290051.1 - Escherichia phage vB_EcoT_BCU-2, complete genome
# Genome: PV018828.1 - Escherichia phage YW01, complete genome
# Genome: PV018827.1 - Escherichia phage KM01, complete genome
# Genome: PQ999132.1 - Escherichia phage BUCT789, complete genome
# Genome: PQ871103.1 - Escherichia phage vB_Eco_ZCEC15, complete genome
# Genome: PQ860993.1 - Escherichia phage EC.W14-2, complete genome
# Genome: PQ729991.1 - UNVERIFIED: Escherichia phage BUCT823, complete genome
# Genome: PV390658.1 - Escherichia phage vB_EcoM_P54, complete genome
# Genome: PV040721.1 - Escherichia phage BUCT825, complete genome
# Genome: PV295200.1 - Escherichia phage vB_Eco_BCPEco_001, complete genome
# Genome: NC_133119.1 - Escherichia phage EscoHU1 DNA, complete genome
# Genome: PQ179042.1 - Escherichia phage KM02, complete genome
# Genome: PV173775.1 - Escherichia phage GEP001, complete genome
# Genome: PV292302.1 - UNVERIFIED: Escherichia phage Jgk1, complete genome
# Genome: KY985004.1 - Escherichia phage vB_EcoS_SH2, complete genome
# Genome: PQ299149.1 - Escherichia phage LLS, complete genome
# Genome: PQ571288.1 - Escherichia phage EC3-1, complete genome
# Genome: PV102577.1 - Escherichia phage vB_EcoM_BMB16, complete genome
# Genome: PQ799574.1 - Escherichia phage vB_EcoM_Maryam, complete genome
# Genome: PQ759887.1 - Escherichia phage Pu-Krd-SF7, complete genome
# Genome: PQ759886.1 - Escherichia phage Pu-Krd-SF6, complete genome
# Genome: PQ759885.1 - Escherichia phage Pu-Krd-SF5, complete genome
# Genome: PQ759884.1 - Escherichia phage Pu-Krd-SF4, complete genome
# Genome: PQ631072.1 - Escherichia phage EC.P2, complete genome
# Genome: PQ850632.1 - Escherichia phage VerenaMeyer_Bas76, complete genome
# Genome: PQ850631.1 - Escherichia phage VerenaGrendelmeier_Bas101, complete genome
# Genome: PQ850630.1 - Escherichia phage TanjaMuster_Bas81, complete genome
# Genome: PQ850629.1 - Escherichia phage SusanneMuster_Bas79, complete genome
# Genome: PQ850628.1 - Escherichia phage StefiGeyer_Bas88, complete genome
# Genome: PQ850627.1 - Escherichia phage SonjaBuckley_Bas74, complete genome
# Genome: PQ850626.1 - Escherichia phage SkaterBoy_Bas90, complete genome
# Genome: PQ850625.1 - Escherichia phage SandraMuster_Bas78, complete genome
# Genome: PQ850624.1 - Escherichia phage RuthEpting_Bas85, complete genome
# Genome: PQ850623.1 - Escherichia phage RudolfBernhard_Bas96, complete genome
# Genome: PQ850622.1 - Escherichia phage OliverMaurmann_Bas86, complete genome
# Genome: PQ850621.1 - Escherichia phage NicoleGrasset_Bas72, complete genome
# Genome: PQ850620.1 - Escherichia phage MeretOppenheim_Bas102, complete genome
# Genome: PQ850619.1 - Escherichia phage MarieHeimVoegtlin_Bas70, complete genome
# Genome: PQ850618.1 - Escherichia phage ManiWeber_Bas99, complete genome
# Genome: PQ850617.1 - Escherichia phage ManiMatter_Bas94, complete genome
# Genome: PQ850616.1 - Escherichia phage Louie, complete genome
# Genome: PQ850615.1 - Escherichia phage LotteLoewe_Bas71, complete genome
# Genome: PQ850614.1 - Escherichia phage LorandFenyves_Bas91, complete genome
# Genome: PQ850613.1 - Escherichia phage KarlSchell_Bas89, complete genome
# Genome: PQ850612.1 - Escherichia phage KarinMuster_Bas82, complete genome
# Genome: PQ850611.1 - Escherichia phage JohannBuxtorf_Bas84, complete genome
# Genome: PQ850610.1 - Escherichia phage JacquesWildberger_Bas92, complete genome
# Genome: PQ850609.1 - Escherichia phage Huey, complete genome
# Genome: PQ850608.1 - Escherichia phage HermannAdler_Bas98, complete genome
# Genome: PQ850607.1 - Escherichia phage HelliStehle_Bas95, complete genome
# Genome: PQ850606.1 - Escherichia phage HeidiAbel_Bas97, complete genome
# Genome: PQ850605.1 - Escherichia phage HansTraber_Bas100, complete genome
# Genome: PQ850604.1 - Escherichia phage Haito_Bas83, complete genome
# Genome: PQ850603.1 - Escherichia phage GertrudWoker_Bas73, complete genome
# Genome: PQ850602.1 - Escherichia phage EmilieLinder_Bas103, complete genome
# Genome: PQ850601.1 - Escherichia phage ElsieAttenhofer_Bas105, complete genome
# Genome: PQ850600.1 - Escherichia phage Dewey, complete genome
# Genome: PQ850599.1 - Escherichia phage CurroJimenez_Bas106, complete genome
# Genome: PQ850598.1 - Escherichia phage ClaudiaMuster_Bas77, complete genome
# Genome: PQ850597.1 - Escherichia phage ChristineMuster_Bas80, complete genome
# Genome: PQ850596.1 - Escherichia phage AnnaReinhart_Bas75, complete genome
# Genome: PQ850595.1 - Escherichia phage AnnaIndermaur_Bas104, complete genome
# Genome: PQ850594.1 - Escherichia phage AnnaHegner_Bas87, complete genome
# Genome: PQ850593.1 - Escherichia phage AidaStucki_Bas93, complete genome
# Genome: PQ843332.1 - Escherichia phage P-GXEC-L2P5, complete genome
# Genome: PQ878354.1 - Escherichia phage KJC1000 capsid protein gene, partial cds
# Genome: PQ805430.1 - Escherichia phage EK8, complete genome
# Genome: PQ805429.1 - Escherichia phage EK5, complete genome
# Genome: PQ178821.1 - Escherichia phage BMA1, complete genome
# Genome: PQ818761.1 - Escherichia phage EcoM2, complete genome
# Genome: PQ818760.1 - Escherichia phage EcoM1, complete genome
# Genome: PQ799475.1 - Escherichia phage vB_Ec_DUEC01, complete genome
# Genome: PQ657772.1 - Escherichia phage EC.P1, complete genome
# Genome: PQ657771.1 - Escherichia phage EC.P3, complete genome
# Genome: PQ551090.1 - Escherichia phage GR8, complete genome
# Genome: PQ488502.1 - Escherichia phage BUCT632, complete genome
# Genome: PQ783785.1 - Escherichia phage PDP46, complete genome
# Genome: PQ595991.1 - Escherichia phage Psq-1, complete genome

# %% [markdown]
# This part of the script organizes the data into a **pandas DataFrame**. The DataFrame is structured with three columns: **Accession Number**, **Host**, **"Lab_Host"** and **Phage**. This format makes it easier to analyze, manipulate, and export the data as needed.

# %%
df = pd.DataFrame(data, columns=["Accession", "Host", "Lab_Host", "Phage Description"])

df
# Out:
#      Accession                                       Host  \
# 0   PV287706.1                        Escherichia coli 4s
# 1   PV252060.1                           Escherichia coli
# 2   PV204681.1                      Escherichia coli O157
# 3   PP453689.1                 Escherichia coli K12 (RP4)
# 4   PV245935.1                           Escherichia coli
# ..         ...                                        ...
# 95  PQ657771.1                           Escherichia coli
# 96  PQ551090.1                      Escherichia coli CB10
# 97  PQ488502.1                           Escherichia coli
# 98  PQ783785.1  Escherichia coli HS(pFamp)R (ATCC 700891)
# 99  PQ595991.1                           Escherichia coli
#
#                  Lab_Host    Phage Description
# 0                    None          phage Midge
# 1   Escherichia coli M493       phage nithesis
# 2                    None  phage vB_EcoM_JQD51
# 3                    None    phage vB_EcoP_LHP
# 4   Escherichia coli M491          phage kaset
# ..                    ...                  ...
# 95                   None          phage EC.P3
# 96                   None            phage GR8
# 97                   None        phage BUCT632
# 98                   None          phage PDP46
# 99                   None          phage Psq-1
#
# [100 rows x 4 columns]

# %%
df.to_csv("phage_host.csv", index=False)
